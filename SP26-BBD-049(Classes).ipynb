# %%
#Question no 01:
# 1. Create a class Person with attributes name, age, and city.

class Person:
    def __init__(self, name, age, city):
        self.name = name
        self.age = age
        self.city = city

# Creating object
p1 = Person("Ali", 20, "Lahore")

print("Name:", p1.name)
print("Age:", p1.age)
print("City:", p1.city)
# Out:
# Name: Ali
# Age: 20
# City: Lahore

# %%
#Question no 02:
# 2. Create a class Car with attributes make, model, and year.

class Car:
    def __init__(self, make, model, year):
        self.make = make
        self.model = model
        self.year = year

car1 = Car("Toyota", "Corolla", 2022)

print("Make:", car1.make)
print("Model:", car1.model)
print("Year:", car1.year)
# Out:
# Make: Toyota
# Model: Corolla
# Year: 2022

# %%
#Question no 03:
# 3. Create a class Circle with attributes radius
# and methods to calculate area and circumference.

class Circle:
    def __init__(self, radius):
        self.radius = radius

    def area(self):
        return 3.1416 * self.radius * self.radius

    def circumference(self):
        return 2 * 3.1416 * self.radius

circle1 = Circle(5)

print("Area:", circle1.area())
print("Circumference:", circle1.circumference())
# Out:
# Area: 78.54
# Circumference: 31.416

# %%
#Question no 04:
# 4. Create a class Rectangle with attributes length and width
# and methods to calculate area and perimeter.

class Rectangle:
    def __init__(self, length, width):
        self.length = length
        self.width = width

    def area(self):
        return self.length * self.width

    def perimeter(self):
        return 2 * (self.length + self.width)

rect1 = Rectangle(10, 5)

print("Area:", rect1.area())
print("Perimeter:", rect1.perimeter())
# Out:
# Area: 50
# Perimeter: 30

# %%
#Question no 05:
# 5. Create a class Student with attributes name,
# roll_number, and marks. Implement a method
# to calculate average marks.

class Student:
    def __init__(self, name, roll_number, marks):
        self.name = name
        self.roll_number = roll_number
        self.marks = marks

    def average_marks(self):
        return sum(self.marks) / len(self.marks)

student1 = Student("Fatima", "SP26-BBD-049", [85, 90, 78])

print("Name:", student1.name)
print("Average Marks:", student1.average_marks())
# Out:
# Name: Fatima
# Average Marks: 84.33333333333333

# %%
#Question no 06:
# 6. Create a class Book with attributes
# title, author, and publication_year.

class Book:
    def __init__(self, title, author, publication_year):
        self.title = title
        self.author = author
        self.publication_year = publication_year

book1 = Book("Python Basics", "John Smith", 2023)

print("Title:", book1.title)
print("Author:", book1.author)
print("Publication Year:", book1.publication_year)
# Out:
# Title: Python Basics
# Author: John Smith
# Publication Year: 2023

# %%
#Question no 07:
# 7. Create a class Employee with attributes
# name, salary, and designation.

class Employee:
    def __init__(self, name, salary, designation):
        self.name = name
        self.salary = salary
        self.designation = designation

emp1 = Employee("Ahmed", 80000, "Manager")

print("Name:", emp1.name)
print("Salary:", emp1.salary)
print("Designation:", emp1.designation)
# Out:
# Name: Ahmed
# Salary: 80000
# Designation: Manager

# %%
#Question no 08:
# 8. Create a class Bank with attributes
# name, account_number, and balance.
# Implement methods to deposit and withdraw money.

class Bank:
    def __init__(self, name, account_number, balance):
        self.name = name
        self.account_number = account_number
        self.balance = balance

    def deposit(self, amount):
        self.balance += amount
        print(amount, "deposited successfully.")

    def withdraw(self, amount):
        if amount <= self.balance:
            self.balance -= amount
            print(amount, "withdrawn successfully.")
        else:
            print("Insufficient balance.")

bank1 = Bank("Fatima", "12345", 5000)

bank1.deposit(2000)
bank1.withdraw(3000)

print("Remaining Balance:", bank1.balance)
# Out:
# 2000 deposited successfully.
# 3000 withdrawn successfully.
# Remaining Balance: 4000

# %%
#Question no 09:
# 9. Create a class Shape with a method to calculate area.
# Create subclasses Circle, Rectangle, and Triangle.

class Shape:
    def area(self):
        pass

class Circle(Shape):
    def __init__(self, radius):
        self.radius = radius

    def area(self):
        return 3.1416 * self.radius * self.radius

class Rectangle(Shape):
    def __init__(self, length, width):
        self.length = length
        self.width = width

    def area(self):
        return self.length * self.width

class Triangle(Shape):
    def __init__(self, base, height):
        self.base = base
        self.height = height

    def area(self):
        return 0.5 * self.base * self.height

c = Circle(4)
r = Rectangle(6, 3)
t = Triangle(8, 5)

print("Circle Area:", c.area())
print("Rectangle Area:", r.area())
print("Triangle Area:", t.area())
